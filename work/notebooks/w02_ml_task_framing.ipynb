# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinav77040/Flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/abhinav77040/Flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ## My lane as an ML task
#
# I chose the **Page Performance Prediction** lane. This is a **scoring (regression)** task because the model predicts how well a webpage is likely to perform based on historical SEO and content features. The output will help prioritize pages for optimization.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ## Target or proxy
#
# The target is webpage performance. Since future performance is not available, I will use historical metrics such as **clicks_90d**, **impressions_90d**, or **ctr** as proxies. These metrics represent how well a page has performed and can be used to train and evaluate a model.

# %% [markdown]
# ## Target or proxy
#
# The target is webpage performance. Since future performance is not available, I will use historical metrics such as **clicks_90d**, **impressions_90d**, or **ctr** as proxies. These metrics represent how well a page has performed and can be used to train and evaluate a model.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# !git clone https://github.com/abhinav77040/Flyrank-ml-internship.git
# %cd Flyrank-ml-internship
# Out:
# Cloning into 'Flyrank-ml-internship'...
# remote: Enumerating objects: 116, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 116 (delta 32), reused 86 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (116/116), 1.82 MiB | 14.58 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# /content/Flyrank-ml-internship/Flyrank-ml-internship/Flyrank-ml-internship

# %% [markdown]
# ## Unit of analysis
#
# Each row in the dataset represents **one webpage (content page)**. The model will make one prediction for each page using its SEO, content, and engagement features.

# %%
df[[
    "content_id",
    "client_id",
    "clicks_90d",
    "impressions_90d",
    "ctr"
]].head()
# Out:
#              content_id          client_id  clicks_90d  impressions_90d   ctr
# 0  content_304f48230142  client_f369cb89fc          29             3803  0.76
# 1  content_a1fb4e703a9e  client_4e07408562           7            15320  0.05
# 2  content_9aa793d4d895  client_7f2253d7e2          11            12581  0.09
# 3  content_331d6c4de07b  client_19581e27de          58            11751  0.49
# 4  content_d99b7a2d90ca  client_3fdba35f04          24            19140  0.13

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
df["target"] = df["clicks_90d"]

df[["content_id", "clicks_90d", "target"]].head()
# Out:
#              content_id  clicks_90d  target
# 0  content_304f48230142          29      29
# 1  content_a1fb4e703a9e           7       7
# 2  content_9aa793d4d895          11      11
# 3  content_331d6c4de07b          58      58
# 4  content_d99b7a2d90ca          24      24

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
